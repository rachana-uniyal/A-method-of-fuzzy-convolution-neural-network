# %%
# %tensorflow_version 1.x

import tensorflow as tf 
from tensorflow import keras

(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# TensorFlow 1.x selected.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
BATCH_SIZE = 32
EPOCHS = 40
NUM_CLASSES = 10
LEARNING_RATE = 1e-4
MOMENTUM = 0.9

# %%
from matplotlib import pyplot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()

# %%
import cv2
for i in range (0,60000):
  X_train[i] = cv2.blur(X_train[i],(7,7))

for i in range (0,10000):
  X_train[i] = cv2.blur(X_train[i],(7,7))

# %%
from matplotlib import pyplot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, 
                                                  y_train, 
                                                  test_size=0.15, 
                                                  stratify=np.array(y_train), 
                                                  random_state=42)

# %%
from keras.utils import np_utils

Y_train = np_utils.to_categorical(y_train, NUM_CLASSES)
Y_val = np_utils.to_categorical(y_val, NUM_CLASSES)
Y_test = np_utils.to_categorical(y_test, NUM_CLASSES)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np

X_train1 = np.ndarray(shape = (51000, 28,28,3), dtype = 'float32')
X_val1 =   np.ndarray(shape = (9000, 28,28,3), dtype = 'float32')
X_test1 = np.ndarray(shape = (10000,28,28,3), dtype = 'float32')

# %%
import cv2


for i in range(0,51000):
    X_train1[i] = cv2.cvtColor(X_train[i],cv2.COLOR_GRAY2BGR)
    
for i in range(0,9000):
    X_val1[i] = cv2.cvtColor(X_val[i],cv2.COLOR_GRAY2BGR)    
    
    
for i in range(0,10000):
    X_test1[i] = cv2.cvtColor(X_test[i],cv2.COLOR_GRAY2RGB)

# %%
train_f = np.ndarray(shape = (51000,48,48,3), dtype = 'float32')
val_f = np.ndarray(shape = (9000,48,48,3) , dtype = 'float32')
test_f = np.ndarray(shape = (10000,48,48,3) , dtype = 'float32')

# %%
for i in range(0,51000):
     train_f[i] = cv2.resize(X_train1[i],(48,48))
        
for i in range(0,9000):
      val_f[i] = cv2.resize(X_val1[i],(48,48))  
      
for i in range(0,10000):
     test_f[i] = cv2.resize(X_test1[i],(48,48))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.applications import vgg16 as vgg

model = Sequential()
model.add(vgg.VGG16(include_top=False, pooling='avg', weights='imagenet'))

# model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.25))
# model.add(Dense(124, activation='relu'))
model.add(Dropout(0.50))
model.add(Dense(NUM_CLASSES, activation='softmax'))

# model.layers[0].trainable = False
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
from keras import optimizers

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=LEARNING_RATE),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 512)               14714688
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 14,719,818
# Trainable params: 14,719,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = train_f
X_val =   val_f
X_test =  test_f

# %%
print(X_test.shape)
print(X_train.shape)
print(X_val.shape)
# Out:
# (10000, 48, 48, 3)
# (51000, 48, 48, 3)
# (9000, 48, 48, 3)

# %%
print(Y_test.shape)
print(Y_train.shape)
print(Y_val.shape)
# Out:
# (10000, 10)
# (51000, 10)
# (9000, 10)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    horizontal_flip=False)

# %%
train_datagen.fit(X_train)
train_generator = train_datagen.flow(X_train,
                                     Y_train, 
                                     batch_size=BATCH_SIZE)

# %%
val_datagen = ImageDataGenerator(rescale=1. / 255,
    horizontal_flip=False)

val_datagen.fit(X_val)
val_generator = val_datagen.flow(X_val,
                                 Y_val,
                                 batch_size=BATCH_SIZE)

# %%
train_steps_per_epoch = X_train.shape[0] // BATCH_SIZE
val_steps_per_epoch = X_val.shape[0] // BATCH_SIZE

history = model.fit_generator(train_generator,
                              steps_per_epoch=train_steps_per_epoch,
                              validation_data=val_generator,
                              validation_steps=val_steps_per_epoch,
                              epochs=EPOCHS,
                              verbose=1)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/40
# 1593/1593 [==============================] - 55s 34ms/step - loss: 0.0361 - accuracy: 0.9881 - val_loss: 0.0774 - val_accuracy: 0.9953
# Epoch 2/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 5.5211e-04 - val_accuracy: 0.9954
# Epoch 3/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0105 - val_accuracy: 0.9958
# Epoch 4/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.0143 - val_accuracy: 0.9968
# Epoch 5/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 5.5909e-04 - val_accuracy: 0.9971
# Epoch 6/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0054 - val_accuracy: 0.9976
# Epoch 7/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0416 - val_accuracy: 0.9961
# Epoch 8/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0011 - val_accuracy: 0.9976
# Epoch 9/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0603 - val_accuracy: 0.9975
# Epoch 10/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 5.2625e-04 - val_accuracy: 0.9976
# Epoch 11/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 3.3841e-04 - val_accuracy: 0.9973
# Epoch 12/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 2.6753e-04 - val_accuracy: 0.9977
# Epoch 13/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 1.8931e-05 - val_accuracy: 0.9975
# Epoch 14/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0164 - val_accuracy: 0.9975
# Epoch 15/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0133 - val_accuracy: 0.9983
# Epoch 16/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0344 - val_accuracy: 0.9976
# Epoch 17/40
# 1593/1593 [==============================] - 49s 31ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0057 - val_accuracy: 0.9975
# Epoch 18/40
# 1593/1593 [==============================] - 49s 30ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0037 - val_accuracy: 0.9974
# Epoch 19/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0084 - val_accuracy: 0.9974
# Epoch 20/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 5.4262e-06 - val_accuracy: 0.9979
# Epoch 21/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 5.0397e-05 - val_accuracy: 0.9974
# Epoch 22/40
# 1593/1593 [==============================] - 49s 31ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0959 - val_accuracy: 0.9977
# Epoch 23/40
# 1593/1593 [==============================] - 49s 31ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0021 - val_accuracy: 0.9976
# Epoch 24/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 2.3078e-07 - val_accuracy: 0.9979
# Epoch 25/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 2.1207e-05 - val_accuracy: 0.9975
# Epoch 26/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0840 - val_accuracy: 0.9980
# Epoch 27/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 1.0897e-07 - val_accuracy: 0.9974
# Epoch 28/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 9.7411e-06 - val_accuracy: 0.9973
# Epoch 29/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0045 - val_accuracy: 0.9970
# Epoch 30/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0026 - val_accuracy: 0.9974
# Epoch 31/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0000e+00 - val_accuracy: 0.9979
# Epoch 32/40
# 1593/1593 [==============================] - 49s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 1.4943e-05 - val_accuracy: 0.9982
# Epoch 33/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 1.5279e-05 - val_accuracy: 0.9974
# Epoch 34/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 3.2710e-04 - val_accuracy: 0.9982
# Epoch 35/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 6.6143e-06 - val_accuracy: 0.9977
# Epoch 36/40
# 1593/1593 [==============================] - 49s 31ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0342 - val_accuracy: 0.9980
# Epoch 37/40
# 1593/1593 [==============================] - 48s 30ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0665 - val_accuracy: 0.9977
# Epoch 38/40
# 1593/1593 [==============================] - 49s 30ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.8813e-07 - val_accuracy: 0.9980
# Epoch 39/40
# 1593/1593 [==============================] - 49s 30ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1063 - val_accuracy: 0.9980
# Epoch 40/40
# 1593/1593 [==============================] - 49s 30ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0000e+00 - val_accuracy: 0.9979

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.46013752644062045
# Test accuracy: 0.9683797955513

# %%
predictions = model.predict(X_test/255.)

# %%
test_labels = list(y_test.squeeze())
predictions = list(predictions.argmax(axis=1))

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn import metrics

#pred = np.round(model.predict(x_test),0)

labels = ['zero' , 'one' , 'two' , 'three' , 'four' , 'five', 'six' , 'seven' , 'eight' , 'nine']

classification_result = metrics.classification_report(y_test , predictions , target_names=labels)
print(classification_result)
# Out:
#               precision    recall  f1-score   support
#
#         zero       0.89      0.99      0.93       980
#          one       0.91      0.95      0.93      1135
#          two       0.97      0.94      0.95      1032
#        three       0.92      0.71      0.80      1010
#         four       0.99      0.72      0.83       982
#         five       0.74      0.97      0.84       892
#          six       0.97      0.91      0.94       958
#        seven       0.77      0.95      0.85      1028
#        eight       0.82      0.88      0.85       974
#         nine       0.96      0.82      0.88      1009
#
#     accuracy                           0.88     10000
#    macro avg       0.89      0.88      0.88     10000
# weighted avg       0.90      0.88      0.88     10000
